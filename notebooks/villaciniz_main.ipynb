# %%
import bs4
import requests
from urllib.parse import urlparse, parse_qs
import pandas as pd
import unicodedata

# %%
urls = []

for page_number in range(1, 142):

    URL = "https://www.villaciniz.com.tr/arama-sonuclari?s=" + str(page_number)
    response = requests.get(URL)
    response.encoding = "utf-8"  
    html_parsed = bs4.BeautifulSoup(response.text, "html.parser")

    villa_urls = set([url["href"].strip() for url in html_parsed.select("div#searchResult div.carousel-item a")])
    for url in villa_urls:
        urls.append("https://villaciniz.com.tr" + url)
        
    if page_number % 10 == 0:
        print(f"{page_number} pages have been checked!")
        
print(f"\n---OPERATION HAS BEEN COMPLETED!---")
print(f"{page_number} pages have been checked!")
print(f"Total Villa URL: {len(urls)}")
# Out:
# 10 pages have been checked!
# 20 pages have been checked!
# 30 pages have been checked!
# 40 pages have been checked!
# 50 pages have been checked!
# 60 pages have been checked!
# 70 pages have been checked!
# 80 pages have been checked!
# 90 pages have been checked!
# 100 pages have been checked!
# 110 pages have been checked!
# 120 pages have been checked!
# 130 pages have been checked!
# 140 pages have been checked!
#
# ---OPERATION HAS BEEN COMPLETED!---
# 141 pages have been checked!
# Total Villa URL: 1684

# %%
names = []
addresses = []
photos = []
latitudes = []
longitudes = []
average_prices = []
q1_prices = []
q2_prices = []
q3_prices = []
q4_prices = []
descriptions = []
guests = []
bedrooms = []
bathrooms = []
ids = []

URL_ERRORS = []
villa_number = 0
for URL in urls:
    try:
        response = requests.get(URL)
        response.encoding = "utf-8" 
        html_parsed = bs4.BeautifulSoup(response.text, "html.parser")
        villa_number += 1
    except:
        print(f"{URL} : URL ERROR!")
        URL_ERRORS.append(URL)
    
    try:
        name = html_parsed.select_one("div.product-title.fs-4.fw-normal.mb-2.pb-1").getText().strip()
        villa_id = name.lower().replace(" ", "")
    except:
        name = None
        villa_id = None
        print(f"Name Error!: {URL}")
        
    try:
        address = html_parsed.select_one("span.fs-5.fw-light.d-block.mb-4").getText().strip()
    except:
        address = None
        print(f"Address Error!: {URL}")
        
    try:
        image = tuple(image_url["href"] for image_url in html_parsed.select("div.container div.row.mb-5.pb-sm-5.mt-3 div.content-start.col-xl-8 div.product-primary-image.rounded-3.position-relative div.d-none a"))
    except:
        image = None
        print(f"Image Error!: {URL}")
        
    try:
        location = html_parsed.select_one("div.col-sm-4.pb-sm-4  div.distances-action div a")["href"].split("@")[1].split(",")[:2]
        latitude, longitude = map(float, location)
    except:
        latitude = None
        longitude = None
        print(f"Location Error!: {URL}")
        
    try:
        villa_prices = [price.getText().strip().replace(".", "") for price in html_parsed.select("div.h-100.d-flex.flex-column.align-items-center.justify-content-center.text-center.py-2")]
        villa_prices = [int(price.replace("₺Gecelik", "")) for price in villa_prices if "Gece" in price]
        avg_price = sum(villa_prices) // len(villa_prices)
        q1_price = avg_price*4 * 0.14
        q2_price = avg_price*4 * 0.32
        q3_price = avg_price*4 * 0.37
        q4_price = avg_price*4 * 0.17
    except:
        print(f"{URL} : PRICE ERROR!")
        avg_price = None
        q1_price = None
        q2_price = None
        q3_price = None
        q4_price = None
        
    try:
        description = unicodedata.normalize("NFKD", "\n".join([desc.getText().strip() for desc in html_parsed.select("#villa-description p")[:-1]]))
    except:
        print(f"{URL} : DESCRIPTION ERROR!")
        description = None
        
    try:
        guest = int(html_parsed.select("span.fs-5.fw-light.d-inline-block")[0].getText()[0])
    except:
        print(f"{URL} : GUEST NUMBER ERROR!")
        guest = None
        
    try:
        bedroom = int(html_parsed.select("span.fs-5.fw-light.d-inline-block")[1].getText()[0])
    except:
        print(f"{URL} : BEDROOM NUMBER ERROR!")
        bedroom = None
        
    try:
        bathroom = int(html_parsed.select("span.fs-5.fw-light.d-inline-block")[2].getText()[0])        
    except:
        print(f"{URL} : BATHROOM NUMBER ERROR!")
        bathroom = None
           
    addresses.append(address)
    ids.append(villa_id)
    names.append(name)
    photos.append(image)
    latitudes.append(latitude)
    longitudes.append(longitude)
    descriptions.append(description)
    average_prices.append(avg_price)
    q1_prices.append(q1_price)
    q2_prices.append(q2_price)
    q3_prices.append(q3_price)
    q4_prices.append(q4_price)
    guests.append(guest)
    bedrooms.append(bedroom)
    bathrooms.append(bathroom)
    
    if villa_number % 75 == 0:
        print(f"{villa_number} villas have been completed!")

print(f"THE OPERATION IS COMPLETED!")
print(f"TOTAL VILLA NUMBER: {villa_number}")
# Out:
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tashan-lidya
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tashan-talya
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tashan-metehan
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tashan-lina
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-paradise-uno
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-eris
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-firoza-4
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-voluptas
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-diamon-3
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-firoza-3
# 75 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-diamon-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-paradise-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-olive-uno
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-diamon-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-harburg
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-zaradise-1-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-zaradise-2-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ramos-3
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-little-royal
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-coban-yildizi
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-asya-bella
# 150 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ezo-luxury
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-arce-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-barbarossa
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-arce
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ramos-5
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-mert-yesilkoy
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-bonus-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-liya
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-in-the-sky
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-terasa
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-bonus-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sifagul
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ezgi-ulugol
# 225 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-rolief
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sabah-gunesi
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-lukka
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-light-house-vier
# 300 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-bayon
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sultan-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tas-konak
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-mercan-patara
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-yakut-patara
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-turkuaz-patara
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kehribar-patara
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-eslem
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-gardenia
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tufan
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kayakoy-bluestar-4
# 375 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-berlin
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-rainbow-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ela-patara
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sacra
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-teraryum-trio
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tawny
# 450 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kirca
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-talia
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kula-house-1
# 525 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kula-house-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-damla-uno
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-litra
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-teraryum-honey
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-silam
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-north
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-emirhan-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-moria
# 600 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-patara-adonis-3
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-patara-adonis-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-beyaz-bulut-dalyan
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-akasya-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-huzurlu-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-makri
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-arda-2
# 675 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-fi
# Name Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sino
# Address Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sino
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sino
# https://villaciniz.com.tr/kiralik-villalar/villa-sino : PRICE ERROR!
# https://villaciniz.com.tr/kiralik-villalar/villa-sino : GUEST NUMBER ERROR!
# https://villaciniz.com.tr/kiralik-villalar/villa-sino : BEDROOM NUMBER ERROR!
# https://villaciniz.com.tr/kiralik-villalar/villa-sino : BATHROOM NUMBER ERROR!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-katmer
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ortac-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-bella-vista
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-light-house-trio
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-angel-rose
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/suit-yigit-1-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-serengeti
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ramos-7
# 750 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-dream
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-salkim
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ortac-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kerem-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ramos-14
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sura-uno
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-neon
# 825 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ortac-3
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-leyla-sultan-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ramos-16
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-likya-milay
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-rima-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-alya-kayakoy
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-gardenya-deluxe
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-gunes-2
# 900 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-water-edge-4
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ortac-4
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-water-edge-5
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kibele-merkur
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-water-edge-6
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-gloksinya
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-james-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-james-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-james-6
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-james-3
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-vivienda
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sura-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-james-5
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-james-4
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kalis-9
# 975 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-frankfurt
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-boheme-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-latavas
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-neptun-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-pastel
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ramos-19
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-palace-small
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-poyraz-fethiye
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-neptun-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-nautilus
# 1050 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-lotus-dalyan-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-talya-kayakoy
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-heva-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-nehir-kayakoy
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-gulsum
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ah-dem
# 1125 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kalis-8
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-rudi
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-celebrity
# 1200 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-elisnira
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-zeybek-evi
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ceremony
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-heva-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-emrah
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-vista-mare
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-yoruk-evi
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-mudur
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-ece-ciftlikkoy
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-eliva-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-elif-ciftlikkoy
# 1275 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-koln
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tiny-stone-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-hanci
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/suit-hanci
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-turunc
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-tiny-stone-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-zulfiye
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-panama-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-lotus-demre
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-olive-garden
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-simurg
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-muhil
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-inziva
# 1350 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/suit-goker-trio
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/suit-lucky
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-dincer-duo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-harika
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kayra--dalyan-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-kalis-7
# 1425 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-olgun-dalyan
# 1500 villas have been completed!
# 1575 villas have been completed!
# 1650 villas have been completed!
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-eleni
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/suit-yigit-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-eldemir-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-eldemir-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-pirlanta-1
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-happy
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-lorenzo
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sirena-alya
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-sirena-harun-
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-pirlanta-2
# Location Error!: https://villaciniz.com.tr/kiralik-villalar/villa-komurluk
# THE OPERATION IS COMPLETED!
# TOTAL VILLA NUMBER: 1684

# %%
data_raw = {
    "ID": ids,
    "Name": names,
    "Address": addresses,
    "Guest Number": guests,
    "Bedroom Number": bedrooms,
    "Bathroom Number": bathrooms,
    "Latitude": latitudes,
    "Longitude": longitudes,
    "Description": descriptions,
    "Photo URLs": photos,
    "Average Price": average_prices,
    "Q1 Price": q1_prices,
    "Q2 Price": q2_prices,
    "Q3 Price": q3_prices,
    "Q4 Price": q4_prices
}

df_raw = pd.DataFrame(data_raw)
df_raw.set_index("ID", inplace=True)
df_raw.to_excel("villaciniz_raw.xlsx")

data_info = {
    "ID": ids,
    "Name": names,
    "Address": addresses,
    "Guest Number": guests,
    "Bedroom Number": bedrooms,
    "Bathroom Number": bathrooms,
    "Description": descriptions,
    "Photo URLs": photos,
    "Latitude": latitudes,
    "Longitude": longitudes
}

df_info = pd.DataFrame(data_info)
df_info.set_index("ID", inplace=True)
df_info.to_excel("villaciniz_info.xlsx")

data_financial = {
    "ID": ids,
    "Average Price": average_prices,
    "Q1 Price": q1_prices,
    "Q2 Price": q2_prices,
    "Q3 Price": q3_prices,
    "Q4 Price": q4_prices   
}

df_financial = pd.DataFrame(data_financial)
df_financial.set_index("ID", inplace=True)
df_financial.to_excel("villaciniz_financial.xlsx")
